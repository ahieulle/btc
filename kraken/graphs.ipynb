# %%
from pandas import read_csv
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

# %%
df = read_csv("./data/prices.csv", sep="\t")

# %%
width = 16
height = 4
plt.figure(figsize=(width, height))
df.index = df["time"]
df["close"].plot(rot=70)
plt.show()
